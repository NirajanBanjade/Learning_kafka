# %%
# !pip install confluent_kafka
# Out:
# Collecting confluent_kafka
#   Downloading confluent_kafka-2.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (23 kB)
# Downloading confluent_kafka-2.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 48.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: confluent_kafka
# Successfully installed confluent_kafka-2.11.0

# %%
# !pip show confluent_kafka
# Out:
# Name: confluent-kafka
# Version: 2.11.0
# Summary: Confluent's Python client for Apache Kafka
# Home-page: https://github.com/confluentinc/confluent-kafka-python
# Author:
# Author-email: "Confluent Inc." <support@confluent.io>
# License:
# Location: /usr/local/lib/python3.11/dist-packages
# Requires:
# Required-by:

# %%
import json
import os
import pandas as pd
from confluent_kafka import Producer


conf = {
    "bootstrap.servers":"pkc-7xoy1.eu-central-1.aws.confluent.cloud:9092",
    "security.protocol":"SASL_SSL",
    "sasl.mechanisms":"PLAIN",
    "sasl.username":"7BMLHO3CU6CHE7GF",
    "sasl.password":"cfltkilI9QI3pflCZuchyuZkpEnYsWd0k9j/swIjgF7CfLhEitfE5RToi0RwztAA",
    "client.id":"json-serial-producer"
}

producer = Producer(conf)

topic="topic_0"
def delivery_report(err,msg):
    if err:
        print(f"Message delivery failed: {err}")
    else:
        print(f"Messagee delivered successdully! key: {msg.key()}")

def read_checkpoint(checkpoint_file):
    if os.path.exists(checkpoint_file):
        with open(checkpoint_file, 'r') as file:
            return int(file.read().strip())
    return 0

#Write checkpoint
def write_checkpoint(checkpoint_file,index):
    with open(checkpoint_file, 'w') as file:
        file.write(str(index))
    print(f"Checkpoint updated to line: {index}")
#Handle date    
def handle_date(obj):
    if isinstance(obj, pd.Timestamp):
        return obj.strftime('%Y-%m-%d %H:%M:%S')
    raise TypeError(f"Object of type {type(obj).__name__} is not JSON serializable")
    
#Stream JSON serially
def stream_json_serially(file_path,checkpoint_file='/kaggle/working/checkpoint.txt'):
    last_sent_index = read_checkpoint(checkpoint_file)
    
    with open(file_path,'r') as file:
        for idx,line in enumerate(file):
            if idx < last_sent_index:
                continue
                
            try:
                record = json.loads(line)
                producer.produce(
                    topic,
                    key=str(record['review_id']),
                    value=json.dumps(record,default=handle_date).encode('utf-8'),
                    callback=delivery_report
                )
                
                producer.flush()
                
                write_checkpoint(checkpoint_file, idx + 1)
                
            except json.JSONDecodeError as e:
                print(f"Failed to decode JSON: {e}")
                
if __name__ == "__main__":
    stream_json_serially('/kaggle/input/yelp-dataset/yelp_academic_dataset_review.json')
# Out:
# Messgae delivered successdully! key: b'jSPLIcj0rgOA4pB7jzDmGQ'
# Checkpoint updated to line: 4526
# %6|1754768569.459|GETSUBSCRIPTIONS|json-serial-producer#producer-4| [thrd:main]: Telemetry client instance id changed from AAAAAAAAAAAAAAAAAAAAAA to u9FghMXGSMGq/voakrbz+Q
# Messgae delivered successdully! key: b'uBK1rNAywFvLswSzatfLJQ'
# Checkpoint updated to line: 4527
# Messgae delivered successdully! key: b'r2PTbqcYj8TNwzsZAbvy3w'
# Checkpoint updated to line: 4528
# Messgae delivered successdully! key: b'sncZcawKWEu4ZZLDiDqEdQ'
# Checkpoint updated to line: 4529
# Messgae delivered successdully! key: b'WgWBquBWLmlOYCKtBEOOFw'
# Checkpoint updated to line: 4530
# Messgae delivered successdully! key: b'L3KnF7BwV94cVMkL2NdGAg'
# Checkpoint updated to line: 4531
# Messgae delivered successdully! key: b'0eEvGZFqrF3dDi2vEBRRgA'
# Checkpoint updated to line: 4532
# Messgae delivered successdully! key: b'WS1W6vRptwqbrENaeCnefg'
# Checkpoint updated to line: 4533
# Messgae delivered successdully! key: b'KGe0DECuXnUKLi_5bdPXjQ'
# Checkpoint updated to line: 4534
# Messgae delivered successdully! key: b'xsJtbYF3r2vg2Vd2A0vwQQ'
# Checkpoint updated to line: 4535
# Messgae delivered successdully! key: b'NnaXJizC3_PP-Qb8TZJZ1g'
# Checkpoint updated to line: 4536
# Messgae delivered successdully! key: b'QBOl4TDCvPMglIz86rZUNg'
# Checkpoint updated to line: 4537
# Messgae delivered successdully! key: b'ar5BKjxzJuPZTM3cruli9w'
# Checkpoint updated to line: 4538
# Messgae delivered successdully! key: b'awKxkCwRPwz1RK88rnOUCA'
# Checkpoint updated to line: 4539
# Messgae delivered successdully! key: b'mfa7ePRpNj4V6Uqui7RGXw'
# Checkpoint updated to line: 4540
# Messgae delivered successdully! key: b'DO3je_K5emcTH23L18mvQw'
# Checkpoint updated to line: 4541
# Messgae delivered successdully! key: b'382MAKuF3DDv5jL_pabr3Q'
# Checkpoint updated to line: 4542
# Messgae delivered successdully! key: b'ukswalurWSxmssk7zZsbJg'
# Checkpoint updated to line: 4543
# Messgae delivered successdully! key: b'mHl68sIOgKcH1PnFa7t4Fw'
# Checkpoint updated to line: 4544
# Messgae delivered successdully! key: b'qaisR2xTb-ybLv9GVB-whg'
# Checkpoint updated to line: 4545
# Messgae delivered successdully! key: b'fjmezj1rejd8qfkzh5dC2g'
# Checkpoint updated to line: 4546
# Messgae delivered successdully! key: b'HoLwVN2GnfyeN2k-IySyrg'
# Checkpoint updated to line: 4547
# Messgae delivered successdully! key: b'aeyMRULZ3ZTVuZ_myKa-wQ'
# Checkpoint updated to line: 4548
# Messgae delivered successdully! key: b'PQ1xH9CmH2mdGZqIJsPFPA'
# Checkpoint updated to line: 4549
# Messgae delivered successdully! key: b'CPMZrWnGkkKNNrg94njO-Q'
# Checkpoint updated to line: 4550
# Messgae delivered successdully! key: b'oTTuahWNWzX_018P6O6_2g'
# Checkpoint updated to line: 4551
# Messgae delivered successdully! key: b'VJHS-DEaG5saL4xvF2iYpg'
# Checkpoint updated to line: 4552
# Messgae delivered successdully! key: b'OLikM9EQ1KIQdN5d6h2Pgw'
# Checkpoint updated to line: 4553
# Messgae delivered successdully! key: b'BByaBisZkYbOS-31JRmo7A'
# Checkpoint updated to line: 4554
# Messgae delivered successdully! key: b'9k5T3XRRntjUWp5FFRWajQ'
# Checkpoint updated to line: 4555
# Messgae delivered successdully! key: b'By5NwRLE6cXJkwrkRh2Lew'
# Checkpoint updated to line: 4556
# Messgae delivered successdully! key: b'WE120ed7iHgYDCao2LaNKQ'
# Checkpoint updated to line: 4557
# Messgae delivered successdully! key: b'sHJiB4raSiLWz0gckq6jIA'
# Checkpoint updated to line: 4558
# Messgae delivered successdully! key: b'tHP5ihPd_W9OzfkKEWdIwA'
# Checkpoint updated to line: 4559
# Messgae delivered successdully! key: b'1GKtmQIqeh1X_4cBE6lq0A'
# Checkpoint updated to line: 4560
# Messgae delivered successdully! key: b'wYy5GbR-QliTH8M91g58hQ'
# Checkpoint updated to line: 4561
# Messgae delivered successdully! key: b'VairgP5nQwKofVCI2E7mAw'
# Checkpoint updated to line: 4562
# Messgae delivered successdully! key: b'0y35jYAB3tbuiDCbnc1Otg'
# Checkpoint updated to line: 4563
# Messgae delivered successdully! key: b'7XuJuRsG3AdAS65nHrMYwg'
# Checkpoint updated to line: 4564
# Messgae delivered successdully! key: b'cnrjGbolqmAg5u5PuB1gJw'
# Checkpoint updated to line: 4565
# Messgae delivered successdully! key: b'MGQg7sfjypn8tq3bA5w42g'
# Checkpoint updated to line: 4566
# Messgae delivered successdully! key: b'miIwXNa5O-ILZaN_S3EH2g'
# Checkpoint updated to line: 4567
# Messgae delivered successdully! key: b'AQUzVGj9SEvL98444lS5IA'
# Checkpoint updated to line: 4568
# Messgae delivered successdully! key: b'wXKEcFdm88_LNHD7EmW_XQ'
# Checkpoint updated to line: 4569
# Messgae delivered successdully! key: b'uZ3jSdNjeDMfMcTIt4DsHw'
# Checkpoint updated to line: 4570
# Messgae delivered successdully! key: b'EIXw_sg3JzR8kCDCSLSHLA'
# Checkpoint updated to line: 4571
# Messgae delivered successdully! key: b'xdnUqmYFvm5YnKkfLJLI7w'
# Checkpoint updated to line: 4572
# Messgae delivered successdully! key: b't22qIqI8xDhW5xxGP1yr4w'
# Checkpoint updated to line: 4573
# Messgae delivered successdully! key: b'TICyx8zmkipThW8M3QqYEw'
# Checkpoint updated to line: 4574
# Messgae delivered successdully! key: b'PHHPkcoNVehIR3116FteoA'
# Checkpoint updated to line: 4575
# Messgae delivered successdully! key: b'UEsbhe1XmoDHr8v8zic-NA'
# Checkpoint updated to line: 4576
# Messgae delivered successdully! key: b'3_tiFAhp3UerjPKRoIV18w'
# Checkpoint updated to line: 4577
# Messgae delivered successdully! key: b'p8vrQNWvKJSOkGx2I07aSw'
# Checkpoint updated to line: 4578
# Messgae delivered successdully! key: b'BmUmY8Xb-QEazYSKv_OpQA'
# Checkpoint updated to line: 4579
# Messgae delivered successdully! key: b'3WAnFLHfQzlzWqBDXDb-sA'
# Checkpoint updated to line: 4580
# Messgae delivered successdully! key: b'6xWFewn7vk4qbWSptzNM4A'
# Checkpoint updated to line: 4581
# Messgae delivered successdully! key: b'uDdeTmLxNC0uIgx7A4xGmg'
# Checkpoint updated to line: 4582
# Messgae delivered successdully! key: b'NlFHjxl5vmiNe0In4DaSlw'
# Checkpoint updated to line: 4583
# Messgae delivered successdully! key: b'y08-_t2xzRhfe75PVGflIg'
# Checkpoint updated to line: 4584
# Messgae delivered successdully! key: b'FprSh7Wr8eHK8Mnh4v34tQ'
# Checkpoint updated to line: 4585
# Messgae delivered successdully! key: b'A3RidKtnIjuu1Us4fJPP-A'
# Checkpoint updated to line: 4586
# Messgae delivered successdully! key: b'RPFO-HPaV9wuV_4rQLQpeA'
# Checkpoint updated to line: 4587
# Messgae delivered successdully! key: b'e-yD6BX8SwJvHbMScNm9xw'
# Checkpoint updated to line: 4588
# Messgae delivered successdully! key: b'2nbhlOPu4bGKqOoNajBBQw'
# Checkpoint updated to line: 4589
# Messgae delivered successdully! key: b'HGDrMS1-cL_rsvouwiC4qA'
# Checkpoint updated to line: 4590
# Messgae delivered successdully! key: b'49VDJVrTqUX1gedopycmTw'
# Checkpoint updated to line: 4591
# Messgae delivered successdully! key: b'gKFg4GyRxbOOgJXzNEO9jg'
# Checkpoint updated to line: 4592
# Messgae delivered successdully! key: b'Ydp6dtfNCtG-OtPZquO7qA'
# Checkpoint updated to line: 4593
# Messgae delivered successdully! key: b'nU_UhJHmytCXLhK5yUC_jA'
# Checkpoint updated to line: 4594
# Messgae delivered successdully! key: b'K09-xWbnYsHAUDuiZXEU2A'
# Checkpoint updated to line: 4595
# Messgae delivered successdully! key: b'Oh4M8Go6pPMsTZBGz9fK_w'
# Checkpoint updated to line: 4596
# Messgae delivered successdully! key: b'PzZYDaGpUPYS4S5nh1oSWA'
# Checkpoint updated to line: 4597
# Messgae delivered successdully! key: b'CQXTlBdM_qGqXTaxL0n3bQ'
# Checkpoint updated to line: 4598
# Messgae delivered successdully! key: b'sNstIkh_7e-n3LTaOHLjXw'
# Checkpoint updated to line: 4599
# Messgae delivered successdully! key: b'pVDmRvMXVqcjRbRAlZOmKA'
# Checkpoint updated to line: 4600
# Messgae delivered successdully! key: b'rG7_lLs9BaHAWFYfmGLnwQ'
# Checkpoint updated to line: 4601
# Messgae delivered successdully! key: b'1rY3Cpe65PAK_swgMYnI5A'
# Checkpoint updated to line: 4602
# Messgae delivered successdully! key: b'4C3-zunlyBIyqzFhV6odeg'
# Checkpoint updated to line: 4603
# Messgae delivered successdully! key: b'sLlJ4VaSU7s79bgBK7CtiQ'
# Checkpoint updated to line: 4604
# Messgae delivered successdully! key: b'DLa7XjzhrqiqNLZxP_D5qA'
# Checkpoint updated to line: 4605
# Messgae delivered successdully! key: b'k5CAAqw1cGz0K2jcNuIpcA'
# Checkpoint updated to line: 4606
# Messgae delivered successdully! key: b'Q0Mxr_od1s4FLnP2TdlJ7g'
# Checkpoint updated to line: 4607
# Messgae delivered successdully! key: b'lrSSP-3amgadBPuDdQkrKQ'
# Checkpoint updated to line: 4608
# Messgae delivered successdully! key: b'_xUhbydbVEspF4WrhToCzw'
# Checkpoint updated to line: 4609
# Messgae delivered successdully! key: b'Mz9O4sq7kShUvoLCs2sEpw'
# Checkpoint updated to line: 4610
# Messgae delivered successdully! key: b'6SAzoyA6e-NKV7U4Sdp5ig'
# Checkpoint updated to line: 4611
# Messgae delivered successdully! key: b'ZcB6VD2dV5oH3KZGPXV2PQ'
# Checkpoint updated to line: 4612
# Messgae delivered successdully! key: b'BwBqCVFKuZ4e-QXNgi5Cwg'
# Checkpoint updated to line: 4613
# Messgae delivered successdully! key: b'Gd6-eZshiY98Csn_fbmoTA'
# Checkpoint updated to line: 4614
# Messgae delivered successdully! key: b'1vcXSr-hZzz4P34fPWE7ww'
# Checkpoint updated to line: 4615
# Messgae delivered successdully! key: b'RkXe6gzU6bfut_Q2W2NpbA'
# Checkpoint updated to line: 4616
# Messgae delivered successdully! key: b'JzZdse6xQZICij9JZoV7hg'
# Checkpoint updated to line: 4617
# Messgae delivered successdully! key: b'1HP3yZN3jT646IlHSo7GZw'
# Checkpoint updated to line: 4618
# Messgae delivered successdully! key: b'6q-XdTfZuc12IjVBTS8QLA'
# Checkpoint updated to line: 4619
# Messgae delivered successdully! key: b'Vm34LhLhglJslQtRHzFLnQ'
# Checkpoint updated to line: 4620
# Messgae delivered successdully! key: b'yVzB86dG6nS7FnfeyLadPA'
# Checkpoint updated to line: 4621
# Messgae delivered successdully! key: b'X_lseu4ykKX0HAidJqfyCw'
# Checkpoint updated to line: 4622
# Messgae delivered successdully! key: b'MzoNUz2z9wEsm9rkzqkNlw'
# Checkpoint updated to line: 4623
# Messgae delivered successdully! key: b'50P3DXJI2XZHzPMB_8epMA'
# Checkpoint updated to line: 4624
# Messgae delivered successdully! key: b'MYw9aJhIIb7cmlvYzZQTZg'
# Checkpoint updated to line: 4625
# Messgae delivered successdully! key: b'Tjwfp4HWCa-hpadERKxLWg'
# Checkpoint updated to line: 4626
# Messgae delivered successdully! key: b'rK-lyzCdjEmdsyTxeDTpsA'
# Checkpoint updated to line: 4627
# Messgae delivered successdully! key: b'WT8NHJHnGdg5Jq9DU5VYzw'
# Checkpoint updated to line: 4628
# Messgae delivered successdully! key: b'JMfMnmvnmaVtDWy2zHjGYQ'
# Checkpoint updated to line: 4629
# Messgae delivered successdully! key: b'TYIiFJkPbpAoB8wFrSUogQ'
# Checkpoint updated to line: 4630
# Messgae delivered successdully! key: b'PywdD8omdRSNOf_jufGysQ'
# Checkpoint updated to line: 4631
# Messgae delivered successdully! key: b'dQ-eHNAaNSCsu9HhAkaZcw'
# Checkpoint updated to line: 4632
# Messgae delivered successdully! key: b'eRYzOskDuxwuzRN9OsfaPg'
# Checkpoint updated to line: 4633
# Messgae delivered successdully! key: b'0HJE3g_Wyhy9u5Mt4hlFIA'
# Checkpoint updated to line: 4634
# Messgae delivered successdully! key: b'zsi3Ey4NPsYcbGMg9UeALA'
# Checkpoint updated to line: 4635
# Messgae delivered successdully! key: b'dYpowJDC-7IbUKaImBekdQ'
# Checkpoint updated to line: 4636
# Messgae delivered successdully! key: b'8Fl_liTivVzRKmhEDirRUQ'
# Checkpoint updated to line: 4637
# Messgae delivered successdully! key: b'jxt9SApvbiElVf4GmGam5w'
# Checkpoint updated to line: 4638
# Messgae delivered successdully! key: b'udYrYSu5YNyJYJONqjIDLQ'
# Checkpoint updated to line: 4639
# Messgae delivered successdully! key: b'M_oqu7NYq2GtWxq0xSwj9w'
# Checkpoint updated to line: 4640
# Messgae delivered successdully! key: b'QSi_mrpTpjBNVU2_HjthiA'
# Checkpoint updated to line: 4641
# Messgae delivered successdully! key: b'IBuTvOO1FmJHykMziMDXZA'
# Checkpoint updated to line: 4642
# Messgae delivered successdully! key: b'FKHuQHUP4AdhQfSrhNbd7g'
# Checkpoint updated to line: 4643
# Messgae delivered successdully! key: b'xW7rZWtjm6bKEoYjlZWEAQ'
# Checkpoint updated to line: 4644
# Messgae delivered successdully! key: b'l84nl5askpQKxV6PvEUAmA'
# Checkpoint updated to line: 4645
# Messgae delivered successdully! key: b'W4wzm2uxJDeOQ3Q92IoebQ'
# Checkpoint updated to line: 4646
# Messgae delivered successdully! key: b'igW8DqXXLShWuq6NPjKVUw'
# Checkpoint updated to line: 4647
# Messgae delivered successdully! key: b'IOmiYoBPtQsY_fh5uA4mXg'
# Checkpoint updated to line: 4648
# Messgae delivered successdully! key: b'ZO4AKQ-n6Hbj9HEnCRp71Q'
# Checkpoint updated to line: 4649
# Messgae delivered successdully! key: b'jBZFSpH4ls0oWwCEPMa33Q'
# Checkpoint updated to line: 4650
# Messgae delivered successdully! key: b'co17QYqjXa57KPxrfzN98A'
# Checkpoint updated to line: 4651
# Messgae delivered successdully! key: b'Gb5Ssf1Ep_S4KKtJNjfzhw'
# Checkpoint updated to line: 4652
# Messgae delivered successdully! key: b'epkD8x60wV1HE-fv7MPjTA'
# Checkpoint updated to line: 4653
# Messgae delivered successdully! key: b'8alvmILiZ6n7ndRCCUmP8g'
# Checkpoint updated to line: 4654
# Messgae delivered successdully! key: b'otnh3OzT0xsK5sckxl7XFQ'
# Checkpoint updated to line: 4655
# Messgae delivered successdully! key: b'mSLSpyYhTs2ak_9hhGKWzw'
# Checkpoint updated to line: 4656
# Messgae delivered successdully! key: b'E2P-zkTszY2v5e-nmukANA'
# Checkpoint updated to line: 4657
# Messgae delivered successdully! key: b'jrg9kd73P5aGr-H_mLFIwg'
# Checkpoint updated to line: 4658
# Messgae delivered successdully! key: b'oa3MfdQvCz_BoU0UXVEDlw'
# Checkpoint updated to line: 4659
# Messgae delivered successdully! key: b'psNFZc4Ld-5hilbLoS6gFA'
# Checkpoint updated to line: 4660
# Messgae delivered successdully! key: b'p_C9_d-ajzh5Uz5HIflakQ'
# Checkpoint updated to line: 4661
# Messgae delivered successdully! key: b'P-CReiSD4gW6nHk7TQhrpg'
# Checkpoint updated to line: 4662
# Messgae delivered successdully! key: b'LDLAwLNU8LmhhVSeWKe-Hg'
# Checkpoint updated to line: 4663
# Messgae delivered successdully! key: b'0gkG18sYjfCf09f3S7KtQw'
# Checkpoint updated to line: 4664
# Messgae delivered successdully! key: b'n1o-LQ8Truw3Ld2jSocSbQ'
# Checkpoint updated to line: 4665
# Messgae delivered successdully! key: b'I56aFwjfMu80SSWHocIGGw'
# Checkpoint updated to line: 4666
# Messgae delivered successdully! key: b'5cIqCPuNvedhnrER0iPRog'
# Checkpoint updated to line: 4667
# Messgae delivered successdully! key: b'-vIuycScTA7SVwHDi1ENeg'
# Checkpoint updated to line: 4668
# Messgae delivered successdully! key: b'Rnsn4UzTBMgi8dFNxaEyxg'
# Checkpoint updated to line: 4669
# Messgae delivered successdully! key: b'977-WLfAhxTNjsjrkxJjdQ'
# Checkpoint updated to line: 4670
# Messgae delivered successdully! key: b'IJrDpV99WCu3w2oSX4EqRg'
# Checkpoint updated to line: 4671
# Messgae delivered successdully! key: b'lx4q3env28RptOudJTnRng'
# Checkpoint updated to line: 4672
# Messgae delivered successdully! key: b'y17wybi8QpRPd3cAXFvn-Q'
# Checkpoint updated to line: 4673
# Messgae delivered successdully! key: b'I3o5hCj1Hyw8bDQgyh-TXA'
# Checkpoint updated to line: 4674
# Messgae delivered successdully! key: b'mlr7sC2XlVXp-ELMMDb6pg'
# Checkpoint updated to line: 4675
# Messgae delivered successdully! key: b'UMMcMeY6__ssj51qGRR6jw'
# Checkpoint updated to line: 4676
# Messgae delivered successdully! key: b'7OOXiuzXfK3CfFpqGExeGQ'
# Checkpoint updated to line: 4677
# Messgae delivered successdully! key: b'e_YCv0cvQWvPiCSUOFat8Q'
# Checkpoint updated to line: 4678
# Messgae delivered successdully! key: b'L4WvY8zRCnuZqG6Hx3wA7A'
# Checkpoint updated to line: 4679
# Messgae delivered successdully! key: b'6TqKBa-HDiq2_W_ip2AItA'
# Checkpoint updated to line: 4680
# Messgae delivered successdully! key: b'Wu99UIXo1jGJeu97KCJzsw'
# Checkpoint updated to line: 4681
# Messgae delivered successdully! key: b'g2dVff8r8JaAc0wJSewlKA'
# Checkpoint updated to line: 4682
# Messgae delivered successdully! key: b'EPqnbvr1tvPXf58fNGhJEw'
# Checkpoint updated to line: 4683
# Messgae delivered successdully! key: b'umB-xYKVpfbaWMdLzc0O5A'
# Checkpoint updated to line: 4684
# Messgae delivered successdully! key: b'0pDuUDNrj_XLvtO090673g'
# Checkpoint updated to line: 4685
# Messgae delivered successdully! key: b'N_3R3MgpNNKIs7LCyuSKGg'
# Checkpoint updated to line: 4686
# Messgae delivered successdully! key: b'G2J-79-_7SkG49J6XgDG_A'
# Checkpoint updated to line: 4687
# Messgae delivered successdully! key: b'UQzHcSPs7vmCAUWbiq6ySw'
# Checkpoint updated to line: 4688
# Messgae delivered successdully! key: b'vpPtDawKQUb1LAbnNtJnxw'
# Checkpoint updated to line: 4689
# Messgae delivered successdully! key: b'ocPjTgIqZJaCnVehOaPmEQ'
# Checkpoint updated to line: 4690
# Messgae delivered successdully! key: b'duSTBLLCdITsf6X_Ktn8Dg'
# Checkpoint updated to line: 4691
# Messgae delivered successdully! key: b'Hra2Q5QSuHGZjqg1SedoAw'
# Checkpoint updated to line: 4692
# Messgae delivered successdully! key: b'ASEs_n8Tn0z16HzTXW7DVQ'
# Checkpoint updated to line: 4693
# Messgae delivered successdully! key: b'6CehSaDzaZHetnnfP3QAPg'
# Checkpoint updated to line: 4694
# Messgae delivered successdully! key: b'_BuQRopU23WAvts9zA-_DQ'
# Checkpoint updated to line: 4695
# Messgae delivered successdully! key: b'YRHFO2w3YHa7MqIzXr9O1g'
# Checkpoint updated to line: 4696
# Messgae delivered successdully! key: b'uTsgn_S3xEz2wNiYislJRw'
# Checkpoint updated to line: 4697
# Messgae delivered successdully! key: b'F4B2-WA5kQqIJgjnekVP6w'
# Checkpoint updated to line: 4698
# Messgae delivered successdully! key: b'D4pBrtKbvzobA9LJGgOgvw'
# Checkpoint updated to line: 4699
# Messgae delivered successdully! key: b'dsVfIROtb5m9VPmU2jqBVw'
# Checkpoint updated to line: 4700
# Messgae delivered successdully! key: b'rPBpY18Aqggn6FABo0y6Hg'
# Checkpoint updated to line: 4701
# Messgae delivered successdully! key: b'7RGcPXsoYgXWt7n1TKWNdA'
# Checkpoint updated to line: 4702
# Messgae delivered successdully! key: b'mNK2cZEfKRiFPG2gH4ZeqA'
# Checkpoint updated to line: 4703
# Messgae delivered successdully! key: b'IHAL3sgNydPDxfXaxUZ_XQ'
# Checkpoint updated to line: 4704
# Messgae delivered successdully! key: b'-ikjrUB6gKNIBYoYmLRZtA'
# Checkpoint updated to line: 4705
# Messgae delivered successdully! key: b'YI5LiNp9jWfZ0rJ_1A3doQ'
# Checkpoint updated to line: 4706
# Messgae delivered successdully! key: b'ZkulRZ_It4fmdw7p5GhCgA'
# Checkpoint updated to line: 4707
# Messgae delivered successdully! key: b'VzWwRe0Df_2j8pxYL3lo1Q'
# Checkpoint updated to line: 4708
# Messgae delivered successdully! key: b'WogN2lOnPMkSBG0swto2lA'
# Checkpoint updated to line: 4709
# Messgae delivered successdully! key: b'8NmVhAjkv4PmAm9Odm0OsQ'
# Checkpoint updated to line: 4710
# Messgae delivered successdully! key: b'ELvgCWNE8Phbsk7h_BAKFQ'
# Checkpoint updated to line: 4711
# Messgae delivered successdully! key: b'dRhU4XWbasQFQ0oDSUdTKQ'
# Checkpoint updated to line: 4712
# Messgae delivered successdully! key: b'_Sp7BsxfzYJh_pTnMEemUw'
# Checkpoint updated to line: 4713
# Messgae delivered successdully! key: b'-rMW2uXk2Jbw5NNxrgbfFg'
# Checkpoint updated to line: 4714
# Messgae delivered successdully! key: b'nhCyIAQ4YRuv3Kvu0t7aNg'
# Checkpoint updated to line: 4715
# Messgae delivered successdully! key: b'nkngnQdlcpHv7g4TLMOIPA'
# Checkpoint updated to line: 4716
# Messgae delivered successdully! key: b'B-HPiNbpRYp9rr9fMQ6E9w'
# Checkpoint updated to line: 4717
# Messgae delivered successdully! key: b'NPg5m9MvZfT091AA5h8aCA'
# Checkpoint updated to line: 4718
# Messgae delivered successdully! key: b'23kzGelQ0D3sHqc-G3ITlw'
# Checkpoint updated to line: 4719
# Messgae delivered successdully! key: b'aRkpcNyrmWNbGhSGDtKMHA'
# Checkpoint updated to line: 4720
# Messgae delivered successdully! key: b'7PPCmQKOHvS33hlr60b8Mg'
# Checkpoint updated to line: 4721
# Messgae delivered successdully! key: b'NKNCz1n4IuztBX7dXCro5A'
# Checkpoint updated to line: 4722
# Messgae delivered successdully! key: b'8OWUC_r_w5G5JhRjI7wcMA'
# Checkpoint updated to line: 4723
# Messgae delivered successdully! key: b'DJe4yEcP5hwpjsfKY37cag'
# Checkpoint updated to line: 4724
# Messgae delivered successdully! key: b'I_KiF2gpPbHt_4-XTNAaGg'
# Checkpoint updated to line: 4725
# Messgae delivered successdully! key: b'MdGvGVtFZdU-ZLoBgIFo3Q'
# Checkpoint updated to line: 4726
# Messgae delivered successdully! key: b'kUKpzjaEZlWFP9-vwjo5AA'
# Checkpoint updated to line: 4727
# Messgae delivered successdully! key: b'0KEdHM7-fONfmLmDjL0p3A'
# Checkpoint updated to line: 4728
# Messgae delivered successdully! key: b'oK4uDS3fneGCgIjac9lWSQ'
# Checkpoint updated to line: 4729
# Messgae delivered successdully! key: b'v0QpUX58whK8JqJNnxYpgA'
# Checkpoint updated to line: 4730
# Messgae delivered successdully! key: b'CzqjdvdDIscS7zgGVw7Zxg'
# Checkpoint updated to line: 4731
# Messgae delivered successdully! key: b'S-Da9QT7AaWLjOefE2m5Cw'
# Checkpoint updated to line: 4732
# Messgae delivered successdully! key: b'VmKraGJ3F80HI9YKOlZvkQ'
# Checkpoint updated to line: 4733
# Messgae delivered successdully! key: b'W9iEbtmrokrzntmlb9HaSw'
# Checkpoint updated to line: 4734
# Messgae delivered successdully! key: b'P0YE9YS5u-t7hxYftuvkDg'
# Checkpoint updated to line: 4735
# Messgae delivered successdully! key: b'yXKPeaUKoiMvZpNNUc3SEg'
# Checkpoint updated to line: 4736
# Messgae delivered successdully! key: b'fEAGKCazWaqd6esES9DFsg'
# Checkpoint updated to line: 4737
# Messgae delivered successdully! key: b'Tg2nuPYpFHFw_OpNsqZA-A'
# Checkpoint updated to line: 4738
# Messgae delivered successdully! key: b'sitF3OSzBvAaqfSB0wMUFQ'
# Checkpoint updated to line: 4739
# Messgae delivered successdully! key: b'rZ_6oX2QrxfMgAUg2L_Ndg'
# Checkpoint updated to line: 4740
# Messgae delivered successdully! key: b'Ml0Tg9mP0CjdNMqtEoKePg'
# Checkpoint updated to line: 4741
# Messgae delivered successdully! key: b'sZdPZLfzDXtCqVVHKiACuw'
# Checkpoint updated to line: 4742
# Messgae delivered successdully! key: b'S2JXC3cKeKv-Biy3zh-A9w'
# Checkpoint updated to line: 4743
# Messgae delivered successdully! key: b'KcGigEED0D6rgTYZ6Tc5Kw'
# Checkpoint updated to line: 4744
# Messgae delivered successdully! key: b'fVOMP7S1YVYPnquLxuTbUw'
# Checkpoint updated to line: 4745
# Messgae delivered successdully! key: b'CEe7C6pRJi9nu7Q3IYqSWA'
# Checkpoint updated to line: 4746
# Messgae delivered successdully! key: b't836MA1XDHg78agHh-vmJA'
# Checkpoint updated to line: 4747
# Messgae delivered successdully! key: b'U1Sr5DvpPE9JHLvgXPR65w'
# Checkpoint updated to line: 4748
# Messgae delivered successdully! key: b'Vdit_MJl1YDeg8onJ7a8kA'
# Checkpoint updated to line: 4749
# Messgae delivered successdully! key: b'W2DTlxFZwswZ8cLab7tC5g'
# Checkpoint updated to line: 4750
# Messgae delivered successdully! key: b'bBsMNLmcfDcR5u0krgDJ5A'
# Checkpoint updated to line: 4751
# Messgae delivered successdully! key: b'PXpbl9f16tq-dUIkufA-zA'
# Checkpoint updated to line: 4752
# Messgae delivered successdully! key: b'_18vRkLmdqVuAwjI__mDaA'
# Checkpoint updated to line: 4753
# Messgae delivered successdully! key: b'0NHC2FrHUSdqsWOA1LuvOA'
# Checkpoint updated to line: 4754
# Messgae delivered successdully! key: b'mXxE14Emo6MXqUOTxHhW0w'
# Checkpoint updated to line: 4755
# Messgae delivered successdully! key: b'bJuW9CwTCKQCAP9ijJcItA'
# Checkpoint updated to line: 4756
# Messgae delivered successdully! key: b'UhbiQ4gMbWBTqpTPNBvrcQ'
# Checkpoint updated to line: 4757
# Messgae delivered successdully! key: b'TYLMC5gKXkKh3fx_SdYQnQ'
# Checkpoint updated to line: 4758
# Messgae delivered successdully! key: b'kMe2VH1uNJIXLYsmAxCMnw'
# Checkpoint updated to line: 4759
# Messgae delivered successdully! key: b'a_k7ooKvsyZ1q_PEsdFdBw'
# Checkpoint updated to line: 4760
# Messgae delivered successdully! key: b'ETSeSPnej6l29ASsPvU0Jw'
# Checkpoint updated to line: 4761
# Messgae delivered successdully! key: b'xLXvHrelFgF8LVTbLu1rRQ'
# Checkpoint updated to line: 4762
# Messgae delivered successdully! key: b'30JqrMb922WinPp_il4xFQ'
# Checkpoint updated to line: 4763
# Messgae delivered successdully! key: b'C_OGK-pK0yz-3FVPZoCf-Q'
# Checkpoint updated to line: 4764
# Messgae delivered successdully! key: b'nmV724_JL4HYel4f7tOY_g'
# Checkpoint updated to line: 4765
# Messgae delivered successdully! key: b'oVaH7LtKk7u0pB0bLvmIUQ'
# Checkpoint updated to line: 4766
# Messgae delivered successdully! key: b'937KzvvvfJos89dRusgSzA'
# Checkpoint updated to line: 4767
# Messgae delivered successdully! key: b'VvAvXbr3mRXSSbtcCakcLQ'
# Checkpoint updated to line: 4768
# Messgae delivered successdully! key: b'nc9MUGqSJpNxBb5ug7nbCA'
# Checkpoint updated to line: 4769
# Messgae delivered successdully! key: b'9wPbZbU6i83MnFhahs4loA'
# Checkpoint updated to line: 4770
# Messgae delivered successdully! key: b'XPirzKZvJq8lYpVR1NA6bw'
# Checkpoint updated to line: 4771
# Messgae delivered successdully! key: b'GJFn9e5GbLLky_OcoCl44A'
# Checkpoint updated to line: 4772
# Messgae delivered successdully! key: b'wNzcdSiMPP0CfOypHfDvRA'
# Checkpoint updated to line: 4773
# Messgae delivered successdully! key: b'PTPLXJENxDvv1iQYjQIF1w'
# Checkpoint updated to line: 4774
# Messgae delivered successdully! key: b'aQAIoNa7AhR5tZ92pqGPug'
# Checkpoint updated to line: 4775
# Messgae delivered successdully! key: b'X2YqdHIaeq5ZO71gJ5DdBw'
# Checkpoint updated to line: 4776
# Messgae delivered successdully! key: b'J87EpAsR8YwyZiKQ1wjclw'
# Checkpoint updated to line: 4777
# Messgae delivered successdully! key: b'T_kAb2NeylB-JdNDKphryw'
# Checkpoint updated to line: 4778
# Messgae delivered successdully! key: b'lIspFq3xCbGGd-U5jjrBrw'
# Checkpoint updated to line: 4779
# Messgae delivered successdully! key: b'jg1IZXh1FWZNkb0UixsWzw'
# Checkpoint updated to line: 4780
# Messgae delivered successdully! key: b'btU2npOsylxhDpQIZgTLGA'
# Checkpoint updated to line: 4781
# Messgae delivered successdully! key: b'bruPYQn90mHncpXvfWQ_CA'
# Checkpoint updated to line: 4782
# Messgae delivered successdully! key: b'lqCebTGorHCZPA62CRirVQ'
# Checkpoint updated to line: 4783
# Messgae delivered successdully! key: b'EeIebnG4LxdcAyWIkJNVJg'
# Checkpoint updated to line: 4784
# Messgae delivered successdully! key: b'dtdXtj17Wl68VhWXxUhJpg'
# Checkpoint updated to line: 4785
# Messgae delivered successdully! key: b'Z0x-gC-cbxdh78Zm2ToLjg'
# Checkpoint updated to line: 4786
# Messgae delivered successdully! key: b'JzXw1ET_L_8n8nl7S_STgg'
# Checkpoint updated to line: 4787
# Messgae delivered successdully! key: b'VMVaW0fZ1b9ZOdC5X2KNiQ'
# Checkpoint updated to line: 4788
# Messgae delivered successdully! key: b'FdegBHlsJhNJ2Zl8sCgrcQ'
# Checkpoint updated to line: 4789
# Messgae delivered successdully! key: b'xqL3eA_QO3P98_1NU1DAaw'
# Checkpoint updated to line: 4790
# Messgae delivered successdully! key: b'N-iamQNm3by8jf1Rac8upQ'
# Checkpoint updated to line: 4791
# Messgae delivered successdully! key: b'kmCmw3Gv6D0LWSfVUYnpIg'
# Checkpoint updated to line: 4792
# Messgae delivered successdully! key: b'csJxpyYlUI-JWXQf9GG39g'
# Checkpoint updated to line: 4793
# Messgae delivered successdully! key: b'7skAHrOL_3JE1pJIqbiVwg'
# Checkpoint updated to line: 4794
# Messgae delivered successdully! key: b'ZLmvC3x_VWCqpgd1grCf7Q'
# Checkpoint updated to line: 4795
# Messgae delivered successdully! key: b'rZp0e4RMaJ4HdNJGYPEgNg'
# Checkpoint updated to line: 4796
# Messgae delivered successdully! key: b'Y24WZxC5IciPEXxsrhYuKw'
# Checkpoint updated to line: 4797
# Messgae delivered successdully! key: b'sfIev9SxDW5SDsPxXqjOYQ'
# Checkpoint updated to line: 4798
# Messgae delivered successdully! key: b'Kn6dBkWJphxN77s4V4e0wA'
# Checkpoint updated to line: 4799
# Messgae delivered successdully! key: b'jZiJgbe90BDf1ZCu4WG_3w'
# Checkpoint updated to line: 4800
# Messgae delivered successdully! key: b'4zSVQzSPc7OkVkHXabSIjA'
# Checkpoint updated to line: 4801
# Messgae delivered successdully! key: b'hk36SBevjO4CXEyaXyoh4Q'
# Checkpoint updated to line: 4802
# Messgae delivered successdully! key: b'_yUjHUGEOtE0vD_X8WKfBw'
# Checkpoint updated to line: 4803
# Messgae delivered successdully! key: b'NnpFscLcfsfZBH0JjuZDcQ'
# Checkpoint updated to line: 4804
# Messgae delivered successdully! key: b'GfVHOrD-RVr2xZr5dxRvVA'
# Checkpoint updated to line: 4805
# Messgae delivered successdully! key: b'dbfxPn8pLxsuWrKlbF63pQ'
# Checkpoint updated to line: 4806
# Messgae delivered successdully! key: b'wBpsn3m5cxFeZ8tpe5Y2Fw'
# Checkpoint updated to line: 4807
# Messgae delivered successdully! key: b'ybXIj3km4WdpZ6EyIdGvOg'
# Checkpoint updated to line: 4808
# Messgae delivered successdully! key: b'_m2V6TTfxLCbmghoQ5OmaA'
# Checkpoint updated to line: 4809
# Messgae delivered successdully! key: b'85rXh5GTCM_QSS9vqqXamQ'
# Checkpoint updated to line: 4810
# Messgae delivered successdully! key: b'nOo0_sLkzHdHk8ORVeJSDQ'
# Checkpoint updated to line: 4811
# Messgae delivered successdully! key: b'LYBQCkNwLY-Z_2By42vwMg'
# Checkpoint updated to line: 4812
# Messgae delivered successdully! key: b'iOFfZQNamYq8f_gl_vmHmg'
# Checkpoint updated to line: 4813
# Messgae delivered successdully! key: b'OvVJtBRgEWlvhyiV_OYFvg'
# Checkpoint updated to line: 4814
# Messgae delivered successdully! key: b'tCNIxvpkckTvma1Ano6HZg'
# Checkpoint updated to line: 4815
# Messgae delivered successdully! key: b'0VvSpwLzL7j6kFmoX8vRyg'
# Checkpoint updated to line: 4816
# Messgae delivered successdully! key: b'XNBN5tQH5DJBYJ94C6KHKw'
# Checkpoint updated to line: 4817
# Messgae delivered successdully! key: b'QDDSJlzQsW_JF8BD6IzikQ'
# Checkpoint updated to line: 4818
# Messgae delivered successdully! key: b'C6_WxrXzrnp7mCARbysUXg'
# Checkpoint updated to line: 4819
# Messgae delivered successdully! key: b'3-ZGJVxW4XmBfjmIFDM4vw'
# Checkpoint updated to line: 4820
# Messgae delivered successdully! key: b'hdu_jQ_E9xEftk1jWFPAug'
# Checkpoint updated to line: 4821
# Messgae delivered successdully! key: b'cYHkV_qlW1xDx-ZLz7OuZw'
# Checkpoint updated to line: 4822
# Messgae delivered successdully! key: b'puzZkRO8VG-OPXSFdCSDYg'
# Checkpoint updated to line: 4823
# Messgae delivered successdully! key: b'QYND0UCUNizzq1y43wjLVg'
# Checkpoint updated to line: 4824
# Messgae delivered successdully! key: b'ynGVvTckodIHCZqQLqv4aw'
# Checkpoint updated to line: 4825
# Messgae delivered successdully! key: b'eUmlz4oZr506IxFND9LLJw'
# Checkpoint updated to line: 4826
# Messgae delivered successdully! key: b'vk3dm7QF8N46JQ9wd5UWTg'
# Checkpoint updated to line: 4827
# Messgae delivered successdully! key: b'0fYfePtXwaklmFM09B5TVg'
# Checkpoint updated to line: 4828
# Messgae delivered successdully! key: b'wrflc6maDTa0k35VkkM1Zg'
# Checkpoint updated to line: 4829
# Messgae delivered successdully! key: b'vRcgbgv_v2l2dFX9O7f_aA'
# Checkpoint updated to line: 4830
# Messgae delivered successdully! key: b'3bmzFuV-Qx7pgtkkkHGpZw'
# Checkpoint updated to line: 4831
# Messgae delivered successdully! key: b'Zk933FCpRBYEuDa8IqawLg'
# Checkpoint updated to line: 4832
# Messgae delivered successdully! key: b'40lILqNR2Wz67EC5PMW8Ug'
# Checkpoint updated to line: 4833
# Messgae delivered successdully! key: b'rq0XoFdjWVenkIA2NG8Stg'
# Checkpoint updated to line: 4834
# Messgae delivered successdully! key: b'jGt3quu_ihSboT4VLZm6zQ'
# Checkpoint updated to line: 4835
# Messgae delivered successdully! key: b'yo5bHBvNaH9cO4ZWqlzviA'
# Checkpoint updated to line: 4836
# Messgae delivered successdully! key: b'qYd0CbpgOFCBo6hsaSCh4g'
# Checkpoint updated to line: 4837
# Messgae delivered successdully! key: b'Bn5P4jFThZiJQEy8mzUXtA'
# Checkpoint updated to line: 4838
# Messgae delivered successdully! key: b'Ky_JL3ITzAOnSGZmRiiiWw'
# Checkpoint updated to line: 4839
# Messgae delivered successdully! key: b'FpKoqLYAm0a5LKO3IWArcQ'
# Checkpoint updated to line: 4840
# Messgae delivered successdully! key: b'uNYOkNm-TEz8yNh-VT612A'
# Checkpoint updated to line: 4841
# Messgae delivered successdully! key: b'-1Gd-K2aNA_jdr2CHmoW0w'
# Checkpoint updated to line: 4842
# Messgae delivered successdully! key: b'j9G5bLf_5X9wOo1xUiDpsw'
# Checkpoint updated to line: 4843
# Messgae delivered successdully! key: b'_R6sqDoalmj8zQTUsacJFw'
# Checkpoint updated to line: 4844
# Messgae delivered successdully! key: b'Ba-9cYMl0iZrBs5na6DpfQ'
# Checkpoint updated to line: 4845
# Messgae delivered successdully! key: b'6X7FWrCUV6NjP_FOmeoY6w'
# Checkpoint updated to line: 4846
# Messgae delivered successdully! key: b'ZgP8HPaCiP-C-sYRk5S86w'
# Checkpoint updated to line: 4847
# Messgae delivered successdully! key: b'qSFHQy6PLtNjxEwaSmsqqw'
# Checkpoint updated to line: 4848
# Messgae delivered successdully! key: b'LfiOfFsoSNAZkm3h9j3fSw'
# Checkpoint updated to line: 4849
# Messgae delivered successdully! key: b'X8DAPs6mw4pvIwn5G9E85Q'
# Checkpoint updated to line: 4850
# Messgae delivered successdully! key: b'HuKsIDJr_0XTAOvgHvb1Qg'
# Checkpoint updated to line: 4851
# Messgae delivered successdully! key: b'F1mEO_K5pu6XJBzfT8Epvw'
# Checkpoint updated to line: 4852
# Messgae delivered successdully! key: b'A8Pf0EWjk1K7LqOtcmtXPw'
# Checkpoint updated to line: 4853
# Messgae delivered successdully! key: b'komrMDXNF4S8gsswNWdf5A'
# Checkpoint updated to line: 4854
# Messgae delivered successdully! key: b'zOIRLnFPm83IjtZ2hQHvKg'
# Checkpoint updated to line: 4855
# Messgae delivered successdully! key: b'XYjkJVKxSGAOEfYdjabXDg'
# Checkpoint updated to line: 4856
# Messgae delivered successdully! key: b'8ookVUVno86qVOsDURfjrA'
# Checkpoint updated to line: 4857
# Messgae delivered successdully! key: b'oTh5xFun8ZuQhUrfU5XGhg'
# Checkpoint updated to line: 4858
# Messgae delivered successdully! key: b'qFgZtnFfvv73CByNPl1BjA'
# Checkpoint updated to line: 4859
# Messgae delivered successdully! key: b'wq8F1Udhmp1AA5w-0Y4Veg'
# Checkpoint updated to line: 4860
# Messgae delivered successdully! key: b'PfKiiXQAg4ZrEXJCXZciKQ'
# Checkpoint updated to line: 4861
# Messgae delivered successdully! key: b'bvr_SX7qXcCTJ3MSL6Rb6w'
# Checkpoint updated to line: 4862
# Messgae delivered successdully! key: b'LR78LvrMbwDtiATitlafcA'
# Checkpoint updated to line: 4863
# Messgae delivered successdully! key: b'nGO0ig0a371mULsmUl-ukg'
# Checkpoint updated to line: 4864
# Messgae delivered successdully! key: b'nCcAr9UDJ22RQqgazFpBog'
# Checkpoint updated to line: 4865
# Messgae delivered successdully! key: b'PemHVNspavC5AFpyhQZMaQ'
# Checkpoint updated to line: 4866
# Messgae delivered successdully! key: b'JLFRR63PB5wp5Dq2vMS25A'
# Checkpoint updated to line: 4867
# Messgae delivered successdully! key: b'gT9XRjpfOyxNuAQzuXu0nw'
# Checkpoint updated to line: 4868
# Messgae delivered successdully! key: b'LryCXyjWyO1-eE7DHFtI8A'
# Checkpoint updated to line: 4869
# Messgae delivered successdully! key: b'tzDJvixRSNcB3fEWxeaLxQ'
# Checkpoint updated to line: 4870
# Messgae delivered successdully! key: b'OhxIJjuDwcA0tRwXImwpeA'
# Checkpoint updated to line: 4871
# Messgae delivered successdully! key: b'xKRcG1cRkxsWwfovUebRxw'
# Checkpoint updated to line: 4872
# Messgae delivered successdully! key: b'l5uPqf9fD16HGceOAxdBAQ'
# Checkpoint updated to line: 4873
# Messgae delivered successdully! key: b'5caagh-CBe9eaLoimRsE1w'
# Checkpoint updated to line: 4874
# Messgae delivered successdully! key: b'4ogfK1azd-TyAh3N49nL8w'
# Checkpoint updated to line: 4875
# Messgae delivered successdully! key: b'U8ym9DZFtB1xOOcWA-qFJw'
# Checkpoint updated to line: 4876
# Messgae delivered successdully! key: b'kEh-Vs51n1VcI8-9BmL9KA'
# Checkpoint updated to line: 4877
# Messgae delivered successdully! key: b'BCkqNC7oxUdF6Ir6iU1veQ'
# Checkpoint updated to line: 4878
# Messgae delivered successdully! key: b'uFQp6bZpJbdtSP936WBNQQ'
# Checkpoint updated to line: 4879
# Messgae delivered successdully! key: b'ZsSEz4VgpeImQDJXdwvbsw'
# Checkpoint updated to line: 4880
# Messgae delivered successdully! key: b'N3rIXao_0B_x24GAPMaiZQ'
# Checkpoint updated to line: 4881
# Messgae delivered successdully! key: b'O5oDHyKTzyoBrY77NJT68w'
# Checkpoint updated to line: 4882
# Messgae delivered successdully! key: b'LpK133btCBEQAVsfw14vJw'
# Checkpoint updated to line: 4883
# Messgae delivered successdully! key: b'LBVXzf-8MbBl7dS5cLXjkQ'
# Checkpoint updated to line: 4884
# Messgae delivered successdully! key: b'HZwKpimFUOKKdP5DGSqsbg'
# Checkpoint updated to line: 4885
# Messgae delivered successdully! key: b'g8AqWdSETIL6jqpfKg-ppg'
# Checkpoint updated to line: 4886
# Messgae delivered successdully! key: b'Cs9fxSxR4w_BR0l3gwlsPQ'
# Checkpoint updated to line: 4887
# Messgae delivered successdully! key: b'BLDnsw2QlYHsHgGMFeQ5kw'
# Checkpoint updated to line: 4888
# Messgae delivered successdully! key: b'x4EMYT1BhSsPBVa7T7q2Rw'
# Checkpoint updated to line: 4889
# Messgae delivered successdully! key: b'UuVu8cq-4dzy5qX2IbG8Bw'
# Checkpoint updated to line: 4890
# Messgae delivered successdully! key: b'VKPmEoj8f9x_cY_j3m8htA'
# Checkpoint updated to line: 4891
# Messgae delivered successdully! key: b'9qfb0MSXznLa_cu-TAYKWw'
# Checkpoint updated to line: 4892
# Messgae delivered successdully! key: b'MKFOk3nJ-fFYY4TVGjuSrQ'
# Checkpoint updated to line: 4893
# Messgae delivered successdully! key: b'57seUymy2vYrBblgbNyPhw'
# Checkpoint updated to line: 4894
# Messgae delivered successdully! key: b'sWvelGfNEhAM1gatKnfwlQ'
# Checkpoint updated to line: 4895
# Messgae delivered successdully! key: b'lj1rdJpUfYGI2IlsuLV2Tg'
# Checkpoint updated to line: 4896
# Messgae delivered successdully! key: b'048-fRFlIH_C-1Yf_kHApQ'
# Checkpoint updated to line: 4897
# Messgae delivered successdully! key: b'oWTXgG0ANgdQ9mjhqeab5g'
# Checkpoint updated to line: 4898
# Messgae delivered successdully! key: b'cZLCXIS7WpBwfDQIKSOh_Q'
# Checkpoint updated to line: 4899
# Messgae delivered successdully! key: b'cVGqwAVVvlBStK-WAhsGKQ'
# Checkpoint updated to line: 4900
# Messgae delivered successdully! key: b'tNFSVz-HBpacywLrH7STeQ'
# Checkpoint updated to line: 4901
# Messgae delivered successdully! key: b'-wjJGDUPMv6qdvxVSmhSsg'
# Checkpoint updated to line: 4902
# Messgae delivered successdully! key: b'qd_me2VUnqz0m9RQDVLpfg'
# Checkpoint updated to line: 4903
# Messgae delivered successdully! key: b'RiVIF3ZQgE8fnNONVX-s0w'
# Checkpoint updated to line: 4904
# Messgae delivered successdully! key: b'2SFnEy6ouZzBE87oNWBMMQ'
# Checkpoint updated to line: 4905
# Messgae delivered successdully! key: b'JHCGSGFpo7_u19v03e1cEw'
# Checkpoint updated to line: 4906
# Messgae delivered successdully! key: b'R0BpobmBSyFHfRmBWaNoUw'
# Checkpoint updated to line: 4907
# Messgae delivered successdully! key: b'_zssVgZMN_341zSkGpVWSg'
# Checkpoint updated to line: 4908
# Messgae delivered successdully! key: b'BCGDFa5RQLneWvfZsGOnPA'
# Checkpoint updated to line: 4909
# Messgae delivered successdully! key: b'zhXs9aaW2nn7lsAD1Yhujg'
# Checkpoint updated to line: 4910
# Messgae delivered successdully! key: b'U6bFqscXzexcUOxY2n2pyA'
# Checkpoint updated to line: 4911
# Messgae delivered successdully! key: b'cXfd-ikyYYRJRbn2GXVSlQ'
# Checkpoint updated to line: 4912
# Messgae delivered successdully! key: b'kgKKD4Bde6bNhEIQtLkRLA'
# Checkpoint updated to line: 4913
# Messgae delivered successdully! key: b'kpukSGb00KeYlKNXLdZr2Q'
# Checkpoint updated to line: 4914
# Messgae delivered successdully! key: b'H0iax4N6VjcNKv3xEbcBrg'
# Checkpoint updated to line: 4915
# Messgae delivered successdully! key: b'0QJAMs7aGElUvzZgQ6tHkg'
# Checkpoint updated to line: 4916
# Messgae delivered successdully! key: b'h7p_u0cDPojILgYaGB3YtQ'
# Checkpoint updated to line: 4917
# Messgae delivered successdully! key: b'_98NDgMbl2Ri12BjDuczNA'
# Checkpoint updated to line: 4918
# Messgae delivered successdully! key: b'Q-PDBGZo1ZlKMBOg6Izkzg'
# Checkpoint updated to line: 4919
# Messgae delivered successdully! key: b'JXZcMZ9pcBL7mAhyJJ6U9g'
# Checkpoint updated to line: 4920
# Messgae delivered successdully! key: b'toLAMehjvvW3JV33WjboRA'
# Checkpoint updated to line: 4921
# Messgae delivered successdully! key: b'z5WgygdWVM8vgfQqe4B_3g'
# Checkpoint updated to line: 4922
# Messgae delivered successdully! key: b'8mQ6Z4RAHymkdo3PkIfjHA'
# Checkpoint updated to line: 4923
# Messgae delivered successdully! key: b'LuknDwBLHlDSSH4eOHu41g'
# Checkpoint updated to line: 4924
# Messgae delivered successdully! key: b'V_2-fmjJTJ_BCruAJfLijw'
# Checkpoint updated to line: 4925
# Messgae delivered successdully! key: b'8xRo9sDKO6PfZCMi1iHTKA'
# Checkpoint updated to line: 4926
# Messgae delivered successdully! key: b'qKdJo5P9rTKwJAk2UaTd6g'
# Checkpoint updated to line: 4927
# Messgae delivered successdully! key: b'aBAj6lpnrFV-W6Jbg9YjvA'
# Checkpoint updated to line: 4928
# Messgae delivered successdully! key: b'n4pXc9EniEcK4TWYb2z8TQ'
# Checkpoint updated to line: 4929
# Messgae delivered successdully! key: b'LuCBW2co_rwn-MKwZ9Lw9Q'
# Checkpoint updated to line: 4930
# Messgae delivered successdully! key: b'r-YKEJT6JjiLIz2YmQ-qNw'
# Checkpoint updated to line: 4931
# Messgae delivered successdully! key: b'vQHXGkWjbcE8SZVz2Bf40w'
# Checkpoint updated to line: 4932
# Messgae delivered successdully! key: b'-QQKeWd-H6zHKqwjd3fU5A'
# Checkpoint updated to line: 4933
# Messgae delivered successdully! key: b'2EUJxZM7-NpZ28aBKQvV2g'
# Checkpoint updated to line: 4934
# Messgae delivered successdully! key: b'xAZuTJf5rvhjo23mYJ06XQ'
# Checkpoint updated to line: 4935
# Messgae delivered successdully! key: b'B7CdXgrMzqz2hf6DCTY56A'
# Checkpoint updated to line: 4936
# Messgae delivered successdully! key: b'JsGKW6_aeDoM13DaaG3HMw'
# Checkpoint updated to line: 4937
# Messgae delivered successdully! key: b'ZKMCyckkJKqhN_XJKQeG5Q'
# Checkpoint updated to line: 4938
# Messgae delivered successdully! key: b'c4lvmPPX6Pt0V1rj1jsWYQ'
# Checkpoint updated to line: 4939
# Messgae delivered successdully! key: b'acmWVnFtquynKvxM13YYww'
# Checkpoint updated to line: 4940
# Messgae delivered successdully! key: b'Xu2WtxUIDQXb-rwkXWGAng'
# Checkpoint updated to line: 4941
# Messgae delivered successdully! key: b'c81v-YG43TDy1QfNeW6aIw'
# Checkpoint updated to line: 4942
# Messgae delivered successdully! key: b'gx92zfKLC767cNBzw6D0-w'
# Checkpoint updated to line: 4943
# Messgae delivered successdully! key: b'yNAmr9WPJjC05wTXiIap9A'
# Checkpoint updated to line: 4944
# Messgae delivered successdully! key: b'Gp7IuGPQzf2dpITBhOJQIA'
# Checkpoint updated to line: 4945
# Messgae delivered successdully! key: b'cOfdFe1jDohXfTfSymf4Ng'
# Checkpoint updated to line: 4946
# Messgae delivered successdully! key: b'OaTfREXTGOLrPJS2GHw-9w'
# Checkpoint updated to line: 4947
# Messgae delivered successdully! key: b'eQqKRmaxYOeeR5w9Jk3Hpg'
# Checkpoint updated to line: 4948
# Messgae delivered successdully! key: b'0nxBmYuAuLEXEvthGT_h1w'
# Checkpoint updated to line: 4949
# Messgae delivered successdully! key: b'CEejGmRXIhRYC0eebFVPug'
# Checkpoint updated to line: 4950
# Messgae delivered successdully! key: b'Ewl_iupJ9LWW7B1NWClf2A'
# Checkpoint updated to line: 4951
# Messgae delivered successdully! key: b'H70ItX85AVsKyVBHOzmVSA'
# Checkpoint updated to line: 4952
# Messgae delivered successdully! key: b'UJmD1Y8X7J8pmCAjnXG9Mw'
# Checkpoint updated to line: 4953
# Messgae delivered successdully! key: b'1vwkrTXzLEZtAP0ukuGBag'
# Checkpoint updated to line: 4954
# Messgae delivered successdully! key: b'0xV7d5DFGnOby2RtCbgF1g'
# Checkpoint updated to line: 4955
# Messgae delivered successdully! key: b'uZowhUHZ9riyVbUhp37J1Q'
# Checkpoint updated to line: 4956
# Messgae delivered successdully! key: b'IWMk_Thy74Be4dEQW2QFrw'
# Checkpoint updated to line: 4957
# Messgae delivered successdully! key: b'8ioV8EsBKcfuCWtuAksN1w'
# Checkpoint updated to line: 4958
# Messgae delivered successdully! key: b'RF6Vr25GR6-J_66-ndCGvg'
# Checkpoint updated to line: 4959
# Messgae delivered successdully! key: b'Ljm5DjUnHRGEnsNJCJhbhg'
# Checkpoint updated to line: 4960
# Messgae delivered successdully! key: b'Ho3_zJ93k21Vydi8xgNYCw'
# Checkpoint updated to line: 4961
# Messgae delivered successdully! key: b'2i7yBFdTTzhBrVQ_RNLXtg'
# Checkpoint updated to line: 4962
# Messgae delivered successdully! key: b'iJnN2vWW2eiydwz1VbqSlg'
# Checkpoint updated to line: 4963
# Messgae delivered successdully! key: b'sItxcvNdyO_Q_EJZ6cubOg'
# Checkpoint updated to line: 4964
# Messgae delivered successdully! key: b'tuZ46L5yZ4oVNjrhXbz0RA'
# Checkpoint updated to line: 4965
# Messgae delivered successdully! key: b'97WDHdWeKwh93miWy0fbZw'
# Checkpoint updated to line: 4966
# Messgae delivered successdully! key: b'WR-tX7kCHkNsv-IF5NK6bw'
# Checkpoint updated to line: 4967
# Messgae delivered successdully! key: b'2cwFTbKqoZwx85JTNga34w'
# Checkpoint updated to line: 4968
# Messgae delivered successdully! key: b'gIb9fcaZ44EQq8CRpO6rVw'
# Checkpoint updated to line: 4969
# Messgae delivered successdully! key: b'0Zzb7BIHEAlaFXCS7-srlw'
# Checkpoint updated to line: 4970
# Messgae delivered successdully! key: b'cEgUTUvkfUUK7hVCbkxU5Q'
# Checkpoint updated to line: 4971
# Messgae delivered successdully! key: b'yJwgnIn8XGlUxQjqOJvM6g'
# Checkpoint updated to line: 4972
# Messgae delivered successdully! key: b'THKc04Y4q8KqMWUOjCUd2g'
# Checkpoint updated to line: 4973
# Messgae delivered successdully! key: b'uRVqGLAdSPvZfAXOuZX9Qw'
# Checkpoint updated to line: 4974
# Messgae delivered successdully! key: b'RaQTYbHYXPJQKXF2cS7YyA'
# Checkpoint updated to line: 4975
# Messgae delivered successdully! key: b'kUHOJuEpGS1uI77SuIaPmQ'
# Checkpoint updated to line: 4976
# Messgae delivered successdully! key: b'dJZ989VhwSmE997ueMVwVQ'
# Checkpoint updated to line: 4977
# Messgae delivered successdully! key: b'Sb_X0QUiPQb-HXWNVIW1-Q'
# Checkpoint updated to line: 4978
# Messgae delivered successdully! key: b'hrvmOcxAY9_IiAwAOJZ9Mg'
# Checkpoint updated to line: 4979
# Messgae delivered successdully! key: b'T7A_Z1USztk3bV15A_lZcQ'
# Checkpoint updated to line: 4980
# Messgae delivered successdully! key: b'opERIUjKJtdCsZcB_g48-A'
# Checkpoint updated to line: 4981
# Messgae delivered successdully! key: b'fhbtgiJ_8cy8gFdovk1wBw'
# Checkpoint updated to line: 4982
# Messgae delivered successdully! key: b'9RqtDf2NDwZB7pu4vjQ79A'
# Checkpoint updated to line: 4983
# Messgae delivered successdully! key: b'00J9BRuGkK4UOpZIiHpKew'
# Checkpoint updated to line: 4984
# Messgae delivered successdully! key: b'94hSTwcWkbuN6tVzKRcMCw'
# Checkpoint updated to line: 4985
# Messgae delivered successdully! key: b'EBYnP3-H0V6tIo60NBTvQw'
# Checkpoint updated to line: 4986
# Messgae delivered successdully! key: b'Ugke7gR6MLOOT2AG5j5ELw'
# Checkpoint updated to line: 4987
# Messgae delivered successdully! key: b'ReIL-9IXONDfkGA3jadHlg'
# Checkpoint updated to line: 4988
# Messgae delivered successdully! key: b'Gw9RC8K2MOCrCVNKlgvx-w'
# Checkpoint updated to line: 4989
# Messgae delivered successdully! key: b'FMM62q3GObynDxWzizO4Sw'
# Checkpoint updated to line: 4990
# Messgae delivered successdully! key: b'wbc_MERlsKHjgwFXkiR3LQ'
# Checkpoint updated to line: 4991
# Messgae delivered successdully! key: b'__hz147wIfO8cjGw5BpZfA'
# Checkpoint updated to line: 4992
# Messgae delivered successdully! key: b'3-N2EuTP78kzEcy-hSNysA'
# Checkpoint updated to line: 4993
# Messgae delivered successdully! key: b'0OVTegj_l-KZa8LttCkgIA'
# Checkpoint updated to line: 4994
# Messgae delivered successdully! key: b'vw_ZNbSmRRnNR8TCxwOMiw'
# Checkpoint updated to line: 4995
# Messgae delivered successdully! key: b'By8WlqTsXoV46IMPWwtMrw'
# Checkpoint updated to line: 4996
# Messgae delivered successdully! key: b'54kBINwBwrymR7eCynYQkA'
# Checkpoint updated to line: 4997
# Messgae delivered successdully! key: b'Naz6TaEzsRBOT__yIvdErQ'
# Checkpoint updated to line: 4998
# Messgae delivered successdully! key: b'03bWH0dNSqEIApT5yVVYVg'
# Checkpoint updated to line: 4999
# Messgae delivered successdully! key: b'iwQBE8o5R6KP1XSRCUAOCg'
# Checkpoint updated to line: 5000
# Messgae delivered successdully! key: b'u6ES_-JHRUhOHtiAu8QMTw'
# Checkpoint updated to line: 5001
# Messgae delivered successdully! key: b'kjz174GO_EmGk5iFmS1X2A'
# Checkpoint updated to line: 5002
# Messgae delivered successdully! key: b'CKAgMltAzLSSK_pnsEOIag'
# Checkpoint updated to line: 5003
# Messgae delivered successdully! key: b'p8wvBiES00X67mrmTbA6XQ'
# Checkpoint updated to line: 5004
# Messgae delivered successdully! key: b'-j6F24VLIfL5aZHOQ1E9ZQ'
# Checkpoint updated to line: 5005
# Messgae delivered successdully! key: b'LpKAdXhXO7WHF5Uo9f5-ZA'
# Checkpoint updated to line: 5006
# Messgae delivered successdully! key: b'JcmiQOlwya3VLfoSIa126w'
# Checkpoint updated to line: 5007
# Messgae delivered successdully! key: b'v4UpBmTMlqQd2vn-rZTHxw'
# Checkpoint updated to line: 5008
# Messgae delivered successdully! key: b'icvmszO2rM-k3piK0bcGWQ'
# Checkpoint updated to line: 5009
# Messgae delivered successdully! key: b'wNpeusLfVx5UnlEVhDQIgw'
# Checkpoint updated to line: 5010
# Messgae delivered successdully! key: b'tO-cghZo8BDtwyHEd1qk9g'
# Checkpoint updated to line: 5011
# Messgae delivered successdully! key: b'Jnm3zWlrLWCkcuLV1bGpnQ'
# Checkpoint updated to line: 5012
# Messgae delivered successdully! key: b'BL26_AIqoxtA2u3bEBlWEw'
# Checkpoint updated to line: 5013
# Messgae delivered successdully! key: b'4WjO2qRKAVlO3jBROhRz1g'
# Checkpoint updated to line: 5014
# Messgae delivered successdully! key: b'zZYgZAhjWoe6KT-2bDprUw'
# Checkpoint updated to line: 5015
# Messgae delivered successdully! key: b'O0LRmV-91QziVWIP-AFkSA'
# Checkpoint updated to line: 5016
# Messgae delivered successdully! key: b'CwdKAfSD1M1OI6AzeFI9EA'
# Checkpoint updated to line: 5017
# Messgae delivered successdully! key: b'WOYsZB2TvgcmzadWVM_Ufw'
# Checkpoint updated to line: 5018
# Messgae delivered successdully! key: b'_3b2n0mgxe5PLNbN5RZPtQ'
# Checkpoint updated to line: 5019
# Messgae delivered successdully! key: b'_hxVKINfqPKb_1H5krTgrQ'
# Checkpoint updated to line: 5020
# Messgae delivered successdully! key: b'pqWQVfAO8ybknQDUg4R5CQ'
# Checkpoint updated to line: 5021
# Messgae delivered successdully! key: b'RiGDWSC_oTekL7LrP7koiQ'
# Checkpoint updated to line: 5022
# Messgae delivered successdully! key: b'bQEVj-nl40DHYKKqaONXng'
# Checkpoint updated to line: 5023
# ...
# Checkpoint updated to line: 7599
# Messgae delivered successdully! key: b'Y0arP1HzbQnlCQdqYlLmxg'
# Checkpoint updated to line: 7600
# Messgae delivered successdully! key: b'CC32upMyRVrZ_WDOiZOI7Q'
# Checkpoint updated to line: 7601
# Messgae delivered successdully! key: b'_dNI9YgOU9S0CCK16taQzQ'
# Checkpoint updated to line: 7602
# Messgae delivered successdully! key: b'zsGdfhRsFl8fU2E8-_W13A'
# Checkpoint updated to line: 7603
# Messgae delivered successdully! key: b'T6MIfM0YNw_jKY3hrH6ROA'
# Checkpoint updated to line: 7604
# Messgae delivered successdully! key: b'dEWrAyg1RcZyQqgw3bcDLw'
# Checkpoint updated to line: 7605
# Messgae delivered successdully! key: b'yg2papcemfrrjz9XYbOAaA'
# Checkpoint updated to line: 7606
# Messgae delivered successdully! key: b'7kh5ygyciPbTYs7741EYKA'
# Checkpoint updated to line: 7607
# Messgae delivered successdully! key: b'9QCmGeU0XnQefUqNvwnAMw'
# Checkpoint updated to line: 7608
# Messgae delivered successdully! key: b'BlCukRAmM5K9jLlMJUx8qw'
# Checkpoint updated to line: 7609
# Messgae delivered successdully! key: b'I2YRAInkDCM8gnMooCAKMA'
# Checkpoint updated to line: 7610
# Messgae delivered successdully! key: b'ojmkguRn_PhqYP-MKB0BXQ'
# Checkpoint updated to line: 7611
# Messgae delivered successdully! key: b'6YllGwEdZUj8fIV6LOSE5g'
# Checkpoint updated to line: 7612
# Messgae delivered successdully! key: b'UUVatd0xokiGBQRQY_OENw'
# Checkpoint updated to line: 7613
# Messgae delivered successdully! key: b'B4nqOw82ztr6lIGKftxZrg'
# Checkpoint updated to line: 7614
# Messgae delivered successdully! key: b'9x-fU9Y-J5QNV8msnYmX-g'
# Checkpoint updated to line: 7615
# Messgae delivered successdully! key: b'iNcHQlmGq7BtF2gatq0BJQ'
# Checkpoint updated to line: 7616
# Messgae delivered successdully! key: b'fmyVW1EJT-4HHK4qTS7Gzw'
# Checkpoint updated to line: 7617
# Messgae delivered successdully! key: b'1o5ksTuy7a4h9hC37E20uQ'
# Checkpoint updated to line: 7618
# Messgae delivered successdully! key: b'XguYG4BEDpnigFIsWLssmQ'
# Checkpoint updated to line: 7619
# Messgae delivered successdully! key: b'GuQiYyMSqKdrTh49q7cOug'
# Checkpoint updated to line: 7620
# Messgae delivered successdully! key: b'es2zMZayuszAuRCZtikYPg'
# Checkpoint updated to line: 7621
# Messgae delivered successdully! key: b'SgtZxMh0wvHQc2bUF3VwXQ'
# Checkpoint updated to line: 7622
# Messgae delivered successdully! key: b'wOnGlaetj8nYTA9v2939Tg'
# Checkpoint updated to line: 7623
# Messgae delivered successdully! key: b'4KzSNn_aBqDiXuw95nCbjA'
# Checkpoint updated to line: 7624
# Messgae delivered successdully! key: b'm8zH2Kx1e11QypkuVKq9fw'
# Checkpoint updated to line: 7625
# Messgae delivered successdully! key: b'TB9w32E2Z4fWd7z0SYMKKQ'
# Checkpoint updated to line: 7626
# Messgae delivered successdully! key: b'3nW3Le7YpfERxnt6tYPA4Q'
# Checkpoint updated to line: 7627
# Messgae delivered successdully! key: b'wa7OqKhk2ZoDI5zT6uSZMg'
# Checkpoint updated to line: 7628
# Messgae delivered successdully! key: b'PBSXq0KMi8ghHcYFWQJkmg'
# Checkpoint updated to line: 7629
# Messgae delivered successdully! key: b'JYRCM4lZN43lpDgXcc1WMw'
# Checkpoint updated to line: 7630
# Messgae delivered successdully! key: b'HlDKz_cPUBJPPiJlBesBjA'
# Checkpoint updated to line: 7631
# Messgae delivered successdully! key: b'98wiayrEV-2jyScWcZQ7wQ'
# Checkpoint updated to line: 7632
# Messgae delivered successdully! key: b'05WQrYkospKgr4unfB-NbQ'
# Checkpoint updated to line: 7633
# Messgae delivered successdully! key: b'fbPymY0Pyv8sbHhOk-7R9g'
# Checkpoint updated to line: 7634
# Messgae delivered successdully! key: b'zFcbIaXelt7dYf0n0hC3rw'
# Checkpoint updated to line: 7635
# Messgae delivered successdully! key: b'a6BSG7Sb5uCHVCtVhebJdg'
# Checkpoint updated to line: 7636
# Messgae delivered successdully! key: b'gKc6qY7WO_Ukmo-LIwcwAA'
# Checkpoint updated to line: 7637
# Messgae delivered successdully! key: b't2FxG8KqsjFrXEoOT_VoFw'
# Checkpoint updated to line: 7638
# Messgae delivered successdully! key: b'2Wjq5_cwlkYQFxwxm-POxA'
# Checkpoint updated to line: 7639
# Messgae delivered successdully! key: b'6J6H5YBSZCanJy3F_JUePw'
# Checkpoint updated to line: 7640
# Messgae delivered successdully! key: b'hbgw24lGkMPAOieM4WwG6A'
# Checkpoint updated to line: 7641
# Messgae delivered successdully! key: b'YGDz-fSxXeRl1brhXLssaw'
# Checkpoint updated to line: 7642
# Messgae delivered successdully! key: b'9tQDMbDQPS6D0VOeEtYtFg'
# Checkpoint updated to line: 7643
# Messgae delivered successdully! key: b'9NiL8NWMPWoRf9oNHReELA'
# Checkpoint updated to line: 7644
# Messgae delivered successdully! key: b'fbdhsVODAI7QodGTbH1beQ'
# Checkpoint updated to line: 7645
# Messgae delivered successdully! key: b'DfNjQ5yOagOCztidDLVzlw'
# Checkpoint updated to line: 7646
# Messgae delivered successdully! key: b'4-8Vwl2R-AcONX-EqVapAQ'
# Checkpoint updated to line: 7647
# Messgae delivered successdully! key: b'58R4qoz2ZxOu1nvnab1OHA'
# Checkpoint updated to line: 7648
# Messgae delivered successdully! key: b'yhThEFLIIkbf28wXVicVMA'
# Checkpoint updated to line: 7649
# Messgae delivered successdully! key: b'egqU64yD-a4qQsZUaUWmUg'
# Checkpoint updated to line: 7650
# Messgae delivered successdully! key: b'OBBjV9FeKPqxfXNAjwMzag'
# Checkpoint updated to line: 7651
# Messgae delivered successdully! key: b'BHTD69xacX6g1yVlm0_G5w'
# Checkpoint updated to line: 7652
# Messgae delivered successdully! key: b'oqWg6tImo1wIFjGXzVdJFg'
# Checkpoint updated to line: 7653
# Messgae delivered successdully! key: b'xy7BnOt9jl9W9VZsLwpNJA'
# Checkpoint updated to line: 7654
# Messgae delivered successdully! key: b'g-DHP05_KpUkz8gMbGwbjg'
# Checkpoint updated to line: 7655
# Messgae delivered successdully! key: b'x3JO9kAZAVSVGlViOHwoiw'
# Checkpoint updated to line: 7656
# Messgae delivered successdully! key: b'HR4xC80wL__0FLftDvB7aA'
# Checkpoint updated to line: 7657
# Messgae delivered successdully! key: b'_Ju3CNrMGguLD__9UDrMeA'
# Checkpoint updated to line: 7658
# Messgae delivered successdully! key: b'vmMx3MyCb8eUxpSCrx5nNA'
# Checkpoint updated to line: 7659
# Messgae delivered successdully! key: b'jgWO6xhh4lbCa3A1JHn5jg'
# Checkpoint updated to line: 7660
# Messgae delivered successdully! key: b'NVQ25VVZ0N3XTA1vzr4yfg'
# Checkpoint updated to line: 7661
# Messgae delivered successdully! key: b'VNBITg3VxskSyOrt4wrwFg'
# Checkpoint updated to line: 7662
# Messgae delivered successdully! key: b'0-6lKtgUiWv3-NE3DreMHQ'
# Checkpoint updated to line: 7663
# Messgae delivered successdully! key: b'9bcMawiB7z8Ok1Y7zO43iw'
# Checkpoint updated to line: 7664
# Messgae delivered successdully! key: b'oJInYHyvw1R4yliCx7FUuA'
# Checkpoint updated to line: 7665
# Messgae delivered successdully! key: b'BfLfnex1zA3uWm2Ueb8krg'
# Checkpoint updated to line: 7666
# Messgae delivered successdully! key: b'68kekO9vGU9bxG5G6UT0kw'
# Checkpoint updated to line: 7667
# Messgae delivered successdully! key: b'XQWSfcJj3Xi1H7-o_gNtEQ'
# Checkpoint updated to line: 7668
# Messgae delivered successdully! key: b'Hh4L63rODXJFHXmAYdFIRg'
# Checkpoint updated to line: 7669
# Messgae delivered successdully! key: b'G0P2PqvSRA98s54ithG8nQ'
# Checkpoint updated to line: 7670
# Messgae delivered successdully! key: b'a25gWzYKwgor3zkuNIhe1g'
# Checkpoint updated to line: 7671
# Messgae delivered successdully! key: b'U0akjMGDaez96GR9K0RSdA'
# Checkpoint updated to line: 7672
# Messgae delivered successdully! key: b'9-KQUXge9MkBUuRW4Vs79Q'
# Checkpoint updated to line: 7673
# Messgae delivered successdully! key: b'JDl4nSeRRMZ8k06gOLqW8g'
# Checkpoint updated to line: 7674
# Messgae delivered successdully! key: b'2tzxABDNUbUMNwUrqN7SNw'
# Checkpoint updated to line: 7675
# Messgae delivered successdully! key: b'D4RDeiQQJErIzn-CtXWCqQ'
# Checkpoint updated to line: 7676
# Messgae delivered successdully! key: b'YEqXYPNldsr8EjU6EhCt1Q'
# Checkpoint updated to line: 7677
# Messgae delivered successdully! key: b'kU-CIZOw-tdXd_2lo4nxmA'
# Checkpoint updated to line: 7678
# Messgae delivered successdully! key: b'wLa-TcoR_zWWyDHsC6Ibzw'
# Checkpoint updated to line: 7679
# Messgae delivered successdully! key: b'SgHljn5jyamXF61zC7hPgg'
# Checkpoint updated to line: 7680
# Messgae delivered successdully! key: b'gnFBS3PLXBr7pnTOZUvHug'
# Checkpoint updated to line: 7681
# Messgae delivered successdully! key: b'MUVK2pliwmYvtIWD_rkEpw'
# Checkpoint updated to line: 7682
# Messgae delivered successdully! key: b'jPKV7Xho8vzmT772Es2_qw'
# Checkpoint updated to line: 7683
# Messgae delivered successdully! key: b'HSaNwJWlNLD3dmsPPreLXw'
# Checkpoint updated to line: 7684
# Messgae delivered successdully! key: b'r5iIuyCPWWDNQIm18bCPTA'
# Checkpoint updated to line: 7685
# Messgae delivered successdully! key: b'XLnzU0xUNPaUK-b0NDPZcw'
# Checkpoint updated to line: 7686
# Messgae delivered successdully! key: b'KhlJz19sEEWP2t2tn7GsKg'
# Checkpoint updated to line: 7687
# Messgae delivered successdully! key: b'xuZIgD0hZWbJ_SEbd7rCnQ'
# Checkpoint updated to line: 7688
# Messgae delivered successdully! key: b'0BZN0gp6OjfUAIMxJ7UwmA'
# Checkpoint updated to line: 7689
# Messgae delivered successdully! key: b'e-ImlArRqBhjQcPgvMldJA'
# Checkpoint updated to line: 7690
# Messgae delivered successdully! key: b'G9_0ktrHoeOniRnP-j5T-w'
# Checkpoint updated to line: 7691
# Messgae delivered successdully! key: b'3-XVtxhkD2pJgWzv-QvIAA'
# Checkpoint updated to line: 7692
# Messgae delivered successdully! key: b'9VMfIQiSc9ZmQkyHYf_RcA'
# Checkpoint updated to line: 7693
# Messgae delivered successdully! key: b'JxLYZJiw2TYjk3yDkkE-0g'
# Checkpoint updated to line: 7694
# Messgae delivered successdully! key: b'HrdtJsJrkpW8kcUmpIVArg'
# Checkpoint updated to line: 7695
# Messgae delivered successdully! key: b'yUzlouIRw_BFYKTyY8ftwA'
# Checkpoint updated to line: 7696
# Messgae delivered successdully! key: b'M4j2XtLsPQFyueCG4klPMA'
# Checkpoint updated to line: 7697
# Messgae delivered successdully! key: b'WiOs968H8ohFE87u_XzWtg'
# Checkpoint updated to line: 7698
# Messgae delivered successdully! key: b'AuNllrtfaFT4ugzEWAh_zA'
# Checkpoint updated to line: 7699
# Messgae delivered successdully! key: b'Ak6UV0jc1Yb4KlfzCBLPDg'
# Checkpoint updated to line: 7700
# Messgae delivered successdully! key: b'n1l9j4CNPzKJvixGk333hw'
# Checkpoint updated to line: 7701
# Messgae delivered successdully! key: b'M8Ugk0S5VVDWA6oCEN9stg'
# Checkpoint updated to line: 7702
# Messgae delivered successdully! key: b'75H4Mom1JITA8f9oIMnueQ'
# Checkpoint updated to line: 7703
# Messgae delivered successdully! key: b'7XPEspRPdkQQTY5IN1pTtA'
# Checkpoint updated to line: 7704
# Messgae delivered successdully! key: b'YCKod3lRdV_uNJ4Z2FFJQg'
# Checkpoint updated to line: 7705
# Messgae delivered successdully! key: b't2ZzUjBe5FiOtpNvt1HCdQ'
# Checkpoint updated to line: 7706
# Messgae delivered successdully! key: b'rvFYCXIpnCgq9n2ZaaUTPg'
# Checkpoint updated to line: 7707
# Messgae delivered successdully! key: b'prnle_T0Awx_M8MbIVBIUg'
# Checkpoint updated to line: 7708
# Messgae delivered successdully! key: b'uw9ib7U4VGoMRNSIBlfScQ'
# Checkpoint updated to line: 7709
# Messgae delivered successdully! key: b'xqh2-4N0jrsxunW5F6FgYQ'
# Checkpoint updated to line: 7710
# Messgae delivered successdully! key: b'boqMMCWivZbhU5rWeRrrjA'
# Checkpoint updated to line: 7711
# Messgae delivered successdully! key: b'l-C-37C_fHvxk_Pv1zPKFw'
# Checkpoint updated to line: 7712
# Messgae delivered successdully! key: b'KCGwTjtJ0C1YDPjJYCkEGw'
# Checkpoint updated to line: 7713
# Messgae delivered successdully! key: b'NfiRa5mEkC2w9a9__1NGdw'
# Checkpoint updated to line: 7714
# Messgae delivered successdully! key: b'bZ5taIsxYNakRwy6BQlG0g'
# Checkpoint updated to line: 7715
# Messgae delivered successdully! key: b'cHRsZCE__WU2hctDe5ZPUA'
# Checkpoint updated to line: 7716
# Messgae delivered successdully! key: b'sqjtlKVqo3wldB1OY2VIHg'
# Checkpoint updated to line: 7717
# Messgae delivered successdully! key: b'EaS4LUxNV4IQaTyr7R53fA'
# Checkpoint updated to line: 7718
# Messgae delivered successdully! key: b'hBBQHQee7Bo7Hi_wsd1jLw'
# Checkpoint updated to line: 7719
# Messgae delivered successdully! key: b'zpsdmR8SfyL0eka5HQfCww'
# Checkpoint updated to line: 7720
# Messgae delivered successdully! key: b'yI2_s5hFIBXfRpmsQ8xijg'
# Checkpoint updated to line: 7721
# Messgae delivered successdully! key: b'KsiKb3qtqMYdE7ossXKsdQ'
# Checkpoint updated to line: 7722
# Messgae delivered successdully! key: b'ooO1hufdO1BkFCwQxu03kw'
# Checkpoint updated to line: 7723
# Messgae delivered successdully! key: b'lgChG6VsN_YTKgJjUVm6ag'
# Checkpoint updated to line: 7724
# Messgae delivered successdully! key: b'8nvU0SsG-L0Gc0SfZN8o4Q'
# Checkpoint updated to line: 7725
# Messgae delivered successdully! key: b'vjAzL32RnOxykeGhe93RDQ'
# Checkpoint updated to line: 7726
# Messgae delivered successdully! key: b'8gwNVd08D19kMDY9-1ZmEQ'
# Checkpoint updated to line: 7727
# Messgae delivered successdully! key: b'qxkgQHR__tSFb7aqRbEM7g'
# Checkpoint updated to line: 7728
# Messgae delivered successdully! key: b'yiiylH1BSksRpYe7EDYcvw'
# Checkpoint updated to line: 7729
# Messgae delivered successdully! key: b'kOcgjN2tYGGPq6KNK6_i0w'
# Checkpoint updated to line: 7730
# Messgae delivered successdully! key: b'5VV2lLlynIbE-hqm_nwWrw'
# Checkpoint updated to line: 7731
# Messgae delivered successdully! key: b'52phbw4zW9_EEaU_q9c3bQ'
# Checkpoint updated to line: 7732
# Messgae delivered successdully! key: b'IfU5-pKBOAYRuiDVurjZkw'
# Checkpoint updated to line: 7733
# Messgae delivered successdully! key: b'ptTzXWG5az8tMH094hi_MA'
# Checkpoint updated to line: 7734
# Messgae delivered successdully! key: b'F8eZo3ERF-HsabYVwYR4bQ'
# Checkpoint updated to line: 7735
# Messgae delivered successdully! key: b'c0Z0OMDpiRBwcuOZu9GNfg'
# Checkpoint updated to line: 7736
# Messgae delivered successdully! key: b'FFAjlUd09hLljdiPtihSTw'
# Checkpoint updated to line: 7737
# Messgae delivered successdully! key: b'aIfZ8E3nZ3PEBvYGd6l4MA'
# Checkpoint updated to line: 7738
# Messgae delivered successdully! key: b'5MLiEUM6xTvM7wmh3xADsw'
# Checkpoint updated to line: 7739
# Messgae delivered successdully! key: b'LLIGGDjNdQauQGAK9F1eBQ'
# Checkpoint updated to line: 7740
# Messgae delivered successdully! key: b'0W1lq9-GBU-T8ry_RrdkiQ'
# Checkpoint updated to line: 7741
# Messgae delivered successdully! key: b'9C4KrIedzOq9d7UMK5NRqA'
# Checkpoint updated to line: 7742
# Messgae delivered successdully! key: b'2robwcCIILnwsUWjfQ-Msw'
# Checkpoint updated to line: 7743
# Messgae delivered successdully! key: b'gHkjaOJpmrn64aBBc2L8_g'
# Checkpoint updated to line: 7744
# Messgae delivered successdully! key: b'j9Sy3QWMOiZDNtbPEyqzpQ'
# Checkpoint updated to line: 7745
# Messgae delivered successdully! key: b'SEkOucE7XqLKzm9qXW1cXA'
# Checkpoint updated to line: 7746
# Messgae delivered successdully! key: b'baCTp1CJJF2BvIXiVxXUWw'
# Checkpoint updated to line: 7747
# Messgae delivered successdully! key: b'2EdoQnKwck7FepZtmlgSNw'
# Checkpoint updated to line: 7748
# Messgae delivered successdully! key: b'K01lXxZLJlblhZyOIBBLGg'
# Checkpoint updated to line: 7749
# Messgae delivered successdully! key: b'TvO2ACKDipC-xRfq0VSFHw'
# Checkpoint updated to line: 7750
# Messgae delivered successdully! key: b'U7KbIKsNkWAA-qbPsg9PLQ'
# Checkpoint updated to line: 7751
# Messgae delivered successdully! key: b'YgHVdW6yC8ZfXxmjUGrA1A'
# Checkpoint updated to line: 7752
# Messgae delivered successdully! key: b'fx2YYQm0msdqvD0OPiOEdA'
# Checkpoint updated to line: 7753
# Messgae delivered successdully! key: b'CJ6vMiotQ87GbFrU0cKQXg'
# Checkpoint updated to line: 7754
# Messgae delivered successdully! key: b'0YfLYJSYzMLrDWycpjthPg'
# Checkpoint updated to line: 7755
# Messgae delivered successdully! key: b'LFhNLSEtXxLmgZVy4Fd0Og'
# Checkpoint updated to line: 7756
# Messgae delivered successdully! key: b'BoLIP0vKkjatYz55aucREg'
# Checkpoint updated to line: 7757
# Messgae delivered successdully! key: b'gbhff42d39NiiqAyLtwPEA'
# Checkpoint updated to line: 7758
# Messgae delivered successdully! key: b'uw9ooDApUnbrVmhaRwyijQ'
# Checkpoint updated to line: 7759
# Messgae delivered successdully! key: b'KUVDUajy7MrRlwd6rqKwSQ'
# Checkpoint updated to line: 7760
# Messgae delivered successdully! key: b'L5itflRXHADIq5WWInNSqA'
# Checkpoint updated to line: 7761
# Messgae delivered successdully! key: b'RitM_EgeMAS_cUdf6dPBMg'
# Checkpoint updated to line: 7762
# Messgae delivered successdully! key: b'Wxf7gUoAoD_2CxNOVxJfbQ'
# Checkpoint updated to line: 7763
# Messgae delivered successdully! key: b'cIZFUybskSBb61XiCU4k6w'
# Checkpoint updated to line: 7764
# Messgae delivered successdully! key: b'Q9_ygBtjPLhnoXcToQ2eJA'
# Checkpoint updated to line: 7765
